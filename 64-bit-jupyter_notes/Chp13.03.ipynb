# %%
import pandas as pd
import pandas_datareader.data as web

import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# 그림 13.18은 다음 증권 사이트로부터 해당 기간의 일자별 주가를 출력한 것입니다. 두 데이터를 서로 비교해보면 값이 일치하는 것을 확인할 수 있습니다. 다만 거래량 데이터는 야후 파이낸스가 일의 자리와 십의 자리의 수를 버리는 것과 달리 국내 증권사 사이트는 일의 자릿수까지 정확히 제공합니다.
#
# 야후 파이낸스는 종가와 더불어 수정 종가도 제공합니다. 수정 종가는 분할, 배당, 배분, 신주 발생이 된 경우를 고려해 주식 가격을 조정(adjustment)해둔 가격입니다. 보통 데이터 분석에는 이전 데이터와의 관계를 분석하는 것이 중요하기 때문에 데이터의 연속성을 위해 수정 종가를 사용합니다.

# %%
start = datetime.datetime(2019, 2, 19)
end = datetime.datetime(2020, 1, 10)

gs = web.DataReader("078930.KS", "yahoo", start, end)
gs
# Out:
#                High      Low     Open    Close    Volume  Adj Close
# Date
# 2019-05-02  52600.0  51700.0  51800.0  52100.0   92109.0    52100.0
# 2019-05-15  49850.0  49100.0  49100.0  49650.0  120070.0    49650.0
# 2019-05-17  50500.0  49400.0  49950.0  50300.0  151626.0    50300.0
# 2019-05-20  50500.0  49400.0  50500.0  49400.0  113819.0    49400.0
# 2019-05-21  50500.0  49200.0  49300.0  50100.0  129494.0    50100.0
# 2019-05-22  50100.0  49350.0  49900.0  49950.0   90865.0    49950.0
# 2019-05-23  50000.0  49000.0  50000.0  49550.0  118836.0    49550.0
# 2019-05-24  50200.0  49000.0  49000.0  50100.0  115948.0    50100.0
# 2019-05-27  50000.0  48900.0  50000.0  49250.0  147627.0    49250.0
# 2019-05-28  49950.0  48750.0  49100.0  49950.0  295104.0    49950.0
# 2019-05-29  49950.0  49350.0  49950.0  49400.0  176576.0    49400.0
# 2019-05-30  50600.0  49050.0  49650.0  50500.0  139413.0    50500.0
# 2019-05-31  50400.0  49950.0  50200.0  50100.0  134599.0    50100.0
# ...

# %%
gs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 156 entries, 2019-05-02 to 2020-01-10
# Data columns (total 6 columns):
# High         156 non-null float64
# Low          156 non-null float64
# Open         156 non-null float64
# Close        156 non-null float64
# Volume       156 non-null float64
# Adj Close    156 non-null float64
# dtypes: float64(6)
# memory usage: 8.5 KB

# %%
plt.plot(gs['Adj Close'])
plt.show()
